# %%
import hoi4_civ_calculator as calc
#I set this for Germany, strategy: demilitarize, then go for some econ focuses, rush con 3 
# -rough est of day get, dispersed ind

#general construction speed, 1st val is day of change
#(must have first day) 2nd val must be cumulative
speed_mod = [(1, 1.05), (int(5*30.42),1.15), (int(10*30.42),1.25), (int(27*30.42),1.35)]
unique_spd_mod = {'civ': [(1,0), (int(5*30.42),.1), (int(29*30.42),0)], 
                  #hire advisor day 5, fire advisor day 30
                  'civ_con': [(1,0), (int(5*30.42),.1), (int(15*30.42),.3),(int(29*30.42),.2)],
                  'mil': [(1,.35), (int(8*30.42),.45), (int(15*30.42),.55)],
                  'mil_con': [(1,.35), (int(14*30.42),.65), (int(15*30.42),.75)], 
                  #many mil bonuses also apply -add them here too
                  'ref': [(1,.15), (int(5*30.42),.25), (int(29*30.42),.15)],
                  'inf': [(1,0), (int(5*30.42),.1), (int(29*30.42),0)],
                  'doc': [(1,.25)]} # these are all added to speed_mod
unique_cost_mod = {'civ': [(1,1)], # these are the total mods
                  'civ_con': [(1,0.9), (int(8*30.42),0.8)],
                  'mil': [(1,1)],
                  'mil_con': [(1,0.9), (int(8*30.42),0.8)],
                  'ref': [(1,1)],
                  'inf': [(1,1)],
                  'doc': [(1,1)]}
free_stuff = {'civ': {int(8*30.42):6, int(10*30.42):6, int(26*30.42):12, int(29*30.42):3, int(33*30.42):8}, 
              # in case of conquering or focus #Austria & czech civ guess
              #not sure about trade
              'mil': {int(15*30.42):6, int(26*30.42):7, int(29*30.42):3, int(33*30.42):5}, 
              #key is day had thing at end of day
              'ref': {},
              'inf': {int(13*30.42):{'brandenburg': 2, 'hannover': 3, 'thuringen': 4, 'franken': 3}},
              'doc': {}}
space_mod = [(1,1), (int(14*30.42),1.2), (int(18*30.42),1.4), (int(37*30.42),1.6)] 
#ind tech for max factories
    
con_goods = [(1,0.16), (int(15*30.42),0.11)] #1st val is first day ending with the change
#also depends on stab
daily_reports = [{'civ': 32, 'mil': 28, 'ref': 0, 'doc': 10}]

#state, inf mod, max fact, present fact
inf = {'moselland': [1.7, 10, 3],'rhineland': [1.8, 10, 5], 'brandenburg': [1.8, 12, 9],
       'wurttemberg': [1.8, 8, 6],'sachsen': [1.7, 10, 9],'hannover': [1.7, 8, 5]
       ,'thuringen': [1.6, 8, 1],'franken': [1.7, 6, 2]} #where is this in game files?

#duplicates will be grouped together unless there's no space left in state 
con_queue = calc.make_queue([(('inf', 'moselland'),3),(('inf', 'rhineland'),2),(('civ', 'moselland'),9),
              (('civ', 'rhineland'),7),(('mil', 'wurttemberg'),3),(('mil','westfalen'),5),
              (('mil','sachsen'),3),(('mil','brandenburg'),5),(('mil','hannover'),5),
              (('mil','thuringen'),9),(('mil','franken'),5)])
final_day = 60 #runs this long

calc.init(speed_mod, unique_spd_mod, unique_cost_mod, free_stuff, space_mod, con_goods, 
          daily_reports, inf, con_queue, final_day)
# Out:
# starting ('inf', 'moselland')
# starting ('inf', 'rhineland')

# %%
calc.execute()
# Out:
# day 1
# rhineland civ progress 81.82%
# moselland civ progress 84.27%
# day 2
# rhineland civ progress 82.69%
# moselland civ progress 85.73%
# day 3
# rhineland civ progress 83.57%
# moselland civ progress 87.19%
# day 4
# rhineland civ progress 84.44%
# moselland civ progress 88.65%
# day 5
# rhineland civ progress 85.32%
# moselland civ progress 90.10%
# day 6
# rhineland civ progress 86.19%
# moselland civ progress 91.56%
# day 7
# rhineland civ progress 87.07%
# moselland civ progress 93.02%
# day 8
# rhineland civ progress 87.94%
# moselland civ progress 94.48%
# day 9
# rhineland civ progress 88.82%
# moselland civ progress 95.94%
# day 10
# rhineland civ progress 89.69%
# moselland civ progress 97.40%
# day 11
# rhineland civ progress 90.57%
# moselland civ progress 98.85%
# day 12
# rhineland civ progress 91.44%
# completed civ in moselland
# starting ('civ', 'moselland')
# moselland civ progress 0.31%
# day 13
# rhineland civ progress 92.42%
# moselland civ progress 1.77%
# day 14
# rhineland civ progress 93.39%
# moselland civ progress 3.23%
# day 15
# rhineland civ progress 94.36%
# moselland civ progress 4.69%
# day 16
# rhineland civ progress 95.33%
# moselland civ progress 6.15%
# day 17
# rhineland civ progress 96.31%
# moselland civ progress 7.60%
# day 18
# rhineland civ progress 97.28%
# moselland civ progress 9.06%
# day 19
# rhineland civ progress 98.25%
# moselland civ progress 10.52%
# day 20
# rhineland civ progress 99.22%
# moselland civ progress 11.98%
# day 21
# completed civ in rhineland
# starting ('civ', 'rhineland')
# rhineland civ progress 0.19%
# moselland civ progress 13.44%
# day 22
# rhineland civ progress 1.17%
# moselland civ progress 14.90%
# day 23
# rhineland civ progress 2.14%
# moselland civ progress 16.35%
# day 24
# rhineland civ progress 3.11%
# moselland civ progress 17.81%
# day 25
# rhineland civ progress 4.08%
# moselland civ progress 19.27%
# day 26
# rhineland civ progress 5.06%
# moselland civ progress 20.73%
# day 27
# rhineland civ progress 6.03%
# moselland civ progress 22.19%
# day 28
# rhineland civ progress 7.00%
# moselland civ progress 23.65%
# day 29
# rhineland civ progress 7.97%
# moselland civ progress 25.10%
# day 30
# {'civ': 35, 'mil': 28, 'ref': 0, 'doc': 10}
# rhineland civ progress 8.94%
# moselland civ progress 26.56%
# day 31
# rhineland civ progress 9.92%
# moselland civ progress 28.02%
# day 32
# rhineland civ progress 10.89%
# moselland civ progress 29.48%
# day 33
# rhineland civ progress 11.86%
# moselland civ progress 30.94%
# day 34
# rhineland civ progress 12.83%
# moselland civ progress 32.40%
# day 35
# rhineland civ progress 13.81%
# moselland civ progress 33.85%
# day 36
# rhineland civ progress 14.78%
# moselland civ progress 35.31%
# day 37
# rhineland civ progress 15.75%
# moselland civ progress 36.77%
# day 38
# rhineland civ progress 16.72%
# moselland civ progress 38.23%
# day 39
# rhineland civ progress 17.69%
# moselland civ progress 39.69%
# day 40
# rhineland civ progress 18.67%
# moselland civ progress 41.15%
# day 41
# rhineland civ progress 19.64%
# moselland civ progress 42.60%
# day 42
# rhineland civ progress 20.61%
# moselland civ progress 44.06%
# day 43
# rhineland civ progress 21.58%
# moselland civ progress 45.52%
# day 44
# rhineland civ progress 22.56%
# moselland civ progress 46.98%
# day 45
# rhineland civ progress 23.53%
# moselland civ progress 48.44%
# day 46
# rhineland civ progress 24.50%
# moselland civ progress 49.90%
# day 47
# rhineland civ progress 25.47%
# moselland civ progress 51.35%
# day 48
# rhineland civ progress 26.44%
# moselland civ progress 52.81%
# day 49
# rhineland civ progress 27.42%
# moselland civ progress 54.27%
# day 50
# rhineland civ progress 28.39%
# moselland civ progress 55.73%
# day 51
# rhineland civ progress 29.36%
# moselland civ progress 57.19%
# day 52
# rhineland civ progress 30.33%
# moselland civ progress 58.65%
# day 53
# rhineland civ progress 31.31%
# moselland civ progress 60.10%
# day 54
# rhineland civ progress 32.28%
# moselland civ progress 61.56%
# day 55
# rhineland civ progress 33.25%
# moselland civ progress 63.02%
# day 56
# rhineland civ progress 34.22%
# moselland civ progress 64.48%
# day 57
# rhineland civ progress 35.19%
# moselland civ progress 65.94%
# day 58
# rhineland civ progress 36.17%
# moselland civ progress 67.40%
# day 59
# rhineland civ progress 37.14%
# moselland civ progress 68.85%
# day 60
# {'civ': 35, 'mil': 28, 'ref': 0, 'doc': 10}
# rhineland civ progress 38.11%
# moselland civ progress 70.31%
