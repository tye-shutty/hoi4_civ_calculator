# %%
import hoi4_civ_calculator as calc

speed_mod = [(1, 1.1), (calc.ymd_to_day(1936, 'jun',10),1.2), (calc.ymd_to_day(1936, 'nov',3),1.25),
             (calc.ymd_to_day(1937, 'jan',13),1.35), (calc.ymd_to_day(1938, 'dec',7), 1.3),
            (calc.ymd_to_day(1939, 'mar',28),1.4)]
unique_spd_mod = {'civ': [(1,-0.3), (70,0),(calc.ymd_to_day(1936,'may',28),.1)], 
                  #hire advisor month 5, fire advisor month 30
                  'civ_con': [(1,-0.3), (70,0)],
                  'mil': [(1,-0.3), (70,.2)],
                  'mil_con': [(1,-0.3), (70,.2)], 
                  #many mil bonuses also apply -add them here too
                  'ref': [(1,0)],
                  'inf': [(1,0)],
                  'doc': [(1,0)]} # these are all added to speed_mod
unique_cost_mod = {'civ': [(1,1)], # these are the total mods
                  'civ_con': [(1,1.3), (70,0.8)],
                  'mil': [(1,1)],
                  'mil_con': [(1,1.3), (70,0.8)],
                  'ref': [(1,1)],
                  'inf': [(1,1)],
                  'doc': [(1,1)]}
free_stuff = {'civ': {70*2:4,calc.ymd_to_day(1939, 'sep',1):3,calc.ymd_to_day(1940, 'jan',26):2,
                      calc.ymd_to_day(1940, 'feb',28):5,calc.ymd_to_day(1940, 'jul',16):3}, 
              'mil': {70*8:4,calc.ymd_to_day(1940, 'jan',26):2,calc.ymd_to_day(1940, 'feb',28):6,
                      calc.ymd_to_day(1940, 'jul',20):6},
              'ref': {},
              'inf': {70*3:{'saratov': 3, 'orenburg': 3, 'penza': 3}},
              'doc': {calc.ymd_to_day(1940, 'feb',28):2}}
out_trade  = {1:1, calc.ymd_to_day(1937, 'sep',17):1, calc.ymd_to_day(1937, 'nov',28):3, 
              calc.ymd_to_day(1938, 'jan',25):2,calc.ymd_to_day(1938, 'mar',1):2,
              calc.ymd_to_day(1938, 'jul',20):3,calc.ymd_to_day(1938, 'sep',1):1,
              calc.ymd_to_day(1938, 'dec',7):-11,calc.ymd_to_day(1939, 'jun',17):2,
              calc.ymd_to_day(1939, 'sep',27):1,calc.ymd_to_day(1940, 'feb',28):3,
              calc.ymd_to_day(1940, 'may',3):1,calc.ymd_to_day(1940, 'jul',20):3,
              calc.ymd_to_day(1940, 'oct',26):5}
#oct 27, 1939 60 days 3 civ tungsten
#negative is stopping a trade
in_trade = [(1, 17), (60, 16), (calc.ymd_to_day(1936, 'may',1),14), 
            (calc.ymd_to_day(1936, 'may',15),9),(calc.ymd_to_day(1936, 'apr',15),10),
            (calc.ymd_to_day(1936, 'jun',9),8),(calc.ymd_to_day(1936, 'jul',9),7),
            (calc.ymd_to_day(1936, 'sep',1),8),(calc.ymd_to_day(1937, 'jan',1),11),
            (calc.ymd_to_day(1937, 'aug',1),16),(calc.ymd_to_day(1938, 'jan',1),14),
            (calc.ymd_to_day(1938, 'aug',1),17),(calc.ymd_to_day(1939, 'feb',1),19),
            (calc.ymd_to_day(1939, 'sep',1),29),(calc.ymd_to_day(1940, 'jan',1),32),
            (calc.ymd_to_day(1940, 'aug',1),24)]

space_mod = [(1,1), (calc.ymd_to_day(1936, 'oct',7),1.2), (calc.ymd_to_day(1937, 'mar',9),1.4)]
#ind tech for max factories
    
con_goods = [(1,0.35), (70,0.2), (calc.ymd_to_day(1937, 'sep',15),0.2-8/50*0.05), 
             (calc.ymd_to_day(1938, 'feb',10),0.2-23/50*0.05),(calc.ymd_to_day(1938, 'sep',21),0.2-28/50*0.05)]
#1st val is first day ending with the change
#also depends on stab
daily_reports = [{'civ': 44, 'mil': 32, 'ref': 0, 'doc': 6, 'goods': 26}]

#state, inf mod, max fact, present fact
inf = {'moscow': [1.8, 12, 10],'kharkov': [1.7, 6, 1], 'stalingrad': [1.6, 6, 2],
       'sverdlovsk': [1.6, 6, 3],'saratov': [1.6, 4, 1],'perm': [1.6, 2, 1]
       ,'omsk': [1.4, 4, 1],'orenburg': [1.4, 6, 0],'voroshilovgrad': [1.5, 4, 0], 'penza': [1.4, 4, 0],
       'leningrad': [1.7, 10, 10], 'chelyabinsk': [1.6, 5, 3], 'pskov': [1.6, 4, 0],
      'kazan': [1.6, 4, 1], 'gorki': [1.5, 6, 2], 'ivanovo': [1.5, 4, 0], 'tashkent': [1.5, 6, 3],
      'yaroslavl': [1.5, 5, 1],'magnitogorsk': [1.5, 2, 0], 'ufa': [1.5, 6, 1], 'kuibyshev': [1.5, 4, 2],
      'ryazan': [1.5, 4, 0],'tula': [1.5, 4, 2], 'lipetsk': [1.5, 4, 0], 'kalinin': [1.5, 4, 0],
      'stalino': [1.5, 6, 0],'rostov': [1.5, 6, 2], 'kiev': [1.7, 6, 6]} 

#duplicates will be grouped together unless there's no space left in state 
con_queue1 = calc.make_queue([(('civ', 'moscow'),2),(('civ', 'kharkov'),9),
              (('civ', 'stalingrad'),4),(('civ', 'sverdlovsk'),3),(('civ', 'saratov'),4),
              (('mil', 'moscow'),7),(('mil', 'orenburg'),9),(('mil', 'leningrad'),6),(('mil', 'kiev'),2),
              (('mil', 'kharkov'),3),(('mil', 'stalingrad'),3),(('mil', 'penza'),6),(('mil', 'perm'),2),
              (('mil', 'sverdlovsk'),3),(('mil', 'chelyabinsk'),4),(('mil', 'pskov'),5),
              (('mil', 'kazan'),4),(('mil', 'gorki'),6),(('mil', 'ivanovo'),5),(('mil', 'yaroslavl'),6),
              (('mil', 'tashkent'),6),(('mil', 'ufa'),8),(('mil', 'magnitogorsk'),3),(('mil', 'kuibyshev'),4),
              (('mil', 'ryazan'),6),(('mil', 'lipetsk'),6),(('mil', 'tula'),4),(('mil', 'kalinin'),6),
              (('mil', 'saratov'),1),(('mil', 'stalino'),9),(('mil', 'rostov'),7)])

final_day = calc.ymd_to_day(1941, 'jul', 1) #runs this long

civ22_mil =calc.calculate(daily_reports, con_queue1, inf, final_day, speed_mod, 
                            unique_spd_mod=unique_spd_mod,
                            unique_cost_mod=unique_cost_mod,
                            free_stuff=free_stuff, 
                            in_trade=in_trade,
                            out_trade=out_trade, 
                            space_mod=space_mod, 
                            con_goods=con_goods,
                            debug=False)

# %%
con_queue2 = calc.make_queue([(('civ', 'moscow'),2),(('civ', 'kharkov'),5),
              (('civ', 'stalingrad'),4),(('mil', 'sverdlovsk'),3),(('mil', 'saratov'),4),
              (('mil', 'moscow'),7),(('mil', 'orenburg'),9),(('mil', 'leningrad'),6),(('mil', 'kiev'),2),
              (('mil', 'kharkov'),7),(('mil', 'stalingrad'),3),(('mil', 'penza'),6),(('mil', 'perm'),2),
              (('mil', 'sverdlovsk'),3),(('mil', 'chelyabinsk'),4),(('mil', 'pskov'),5),
              (('mil', 'kazan'),4),(('mil', 'gorki'),6),(('mil', 'ivanovo'),5),(('mil', 'yaroslavl'),6),
              (('mil', 'tashkent'),6),(('mil', 'ufa'),8),(('mil', 'magnitogorsk'),3),(('mil', 'kuibyshev'),4),
              (('mil', 'ryazan'),6),(('mil', 'lipetsk'),6),(('mil', 'tula'),4),(('mil', 'kalinin'),6),
              (('mil', 'saratov'),1),(('mil', 'stalino'),9),(('mil', 'rostov'),7)])
civ11_mil =calc.calculate(daily_reports, con_queue2, inf, final_day, speed_mod, 
                            unique_spd_mod=unique_spd_mod,
                            unique_cost_mod=unique_cost_mod,
                            free_stuff=free_stuff, 
                            in_trade=in_trade,
                            out_trade=out_trade, 
                            space_mod=space_mod, 
                            con_goods=con_goods,
                            debug=False)

# %%
con_queue3 = calc.make_queue([(('mil', 'moscow'),2),(('mil', 'kharkov'),5),
              (('mil', 'stalingrad'),4),(('mil', 'sverdlovsk'),3),(('mil', 'saratov'),4),
              (('mil', 'moscow'),7),(('mil', 'orenburg'),9),(('mil', 'leningrad'),6),(('mil', 'kiev'),2),
              (('mil', 'kharkov'),7),(('mil', 'stalingrad'),3),(('mil', 'penza'),6),(('mil', 'perm'),2),
              (('mil', 'sverdlovsk'),3),(('mil', 'chelyabinsk'),4),(('mil', 'pskov'),5),
              (('mil', 'kazan'),4),(('mil', 'gorki'),6),(('mil', 'ivanovo'),5),(('mil', 'yaroslavl'),6),
              (('mil', 'tashkent'),6),(('mil', 'ufa'),8),(('mil', 'magnitogorsk'),3),(('mil', 'kuibyshev'),4),
              (('mil', 'ryazan'),6),(('mil', 'lipetsk'),6),(('mil', 'tula'),4),(('mil', 'kalinin'),6),
              (('mil', 'saratov'),1),(('mil', 'stalino'),9),(('mil', 'rostov'),7)])
all_mil =calc.calculate(daily_reports, con_queue3, inf, final_day, speed_mod, 
                            unique_spd_mod=unique_spd_mod,
                            unique_cost_mod=unique_cost_mod,
                            free_stuff=free_stuff, 
                            in_trade=in_trade,
                            out_trade=out_trade, 
                            space_mod=space_mod, 
                            con_goods=con_goods,
                            debug=False)

# %%
con_queue4 = calc.make_queue([(('civ', 'moscow'),2),(('civ', 'kharkov'),1),
              (('mil', 'stalingrad'),4),(('mil', 'sverdlovsk'),3),(('mil', 'saratov'),4),
              (('mil', 'moscow'),7),(('mil', 'orenburg'),9),(('mil', 'leningrad'),6),(('mil', 'kiev'),2),
              (('mil', 'kharkov'),11),(('mil', 'stalingrad'),3),(('mil', 'penza'),6),(('mil', 'perm'),2),
              (('mil', 'sverdlovsk'),3),(('mil', 'chelyabinsk'),4),(('mil', 'pskov'),5),
              (('mil', 'kazan'),4),(('mil', 'gorki'),6),(('mil', 'ivanovo'),5),(('mil', 'yaroslavl'),6),
              (('mil', 'tashkent'),6),(('mil', 'ufa'),8),(('mil', 'magnitogorsk'),3),(('mil', 'kuibyshev'),4),
              (('mil', 'ryazan'),6),(('mil', 'lipetsk'),6),(('mil', 'tula'),4),(('mil', 'kalinin'),6),
              (('mil', 'saratov'),1),(('mil', 'stalino'),9),(('mil', 'rostov'),7)])
civ3_mil =calc.calculate(daily_reports, con_queue4, inf, final_day, speed_mod, 
                            unique_spd_mod=unique_spd_mod,
                            unique_cost_mod=unique_cost_mod,
                            free_stuff=free_stuff, 
                            in_trade=in_trade,
                            out_trade=out_trade, 
                            space_mod=space_mod, 
                            con_goods=con_goods,
                            debug=False)

# %%
calc.graph([civ22_mil,civ11_mil,civ3_mil,all_mil], ['mil'],
           ['22 civ then mil','11 civ then mil','3 civ then mil','only mil'],
           [0.5,1])
# Out:
#                         22 civ then mil: mil  11 civ then mil: mil  \
# area of last 1003 days                101387                102337
# area of last 2007 days                139729                145317
#
#                         3 civ then mil: mil  only mil: mil
# area of last 1003 days               100781          99454
# area of last 2007 days               149378         150283
